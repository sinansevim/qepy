# %%
from src import espresso_machine as esma

# %%
#Step 1 - Initialize model
model = esma.project(project_id="P") #Define project
model.set_cores(8) #Define number of prcessing cores
model.get_structure(format='poscar',path='./Research/BP',name='P.poscar') #Load structure
model.set_pseudo(path='./Research/BP')
model.ecutwfc(50) #Wavefunction cut-off
model.k_points(8) #k mesh 
model.degauss(0.01) #degauss value
model.conv_thr("1e-8") #electron convergence threshold

# %%
shift_y = [0,0.25,0]
model.shift_atoms(shift_y)

# %%
#Step 2 - Crystal optimization
model.calculate('vc-relax')

# %%
#Step 3 - Atomic optimization
model.get_structure('vc-relax') #Get vc-relaxed strucutre
model.make_layer(layer_type='mono',direction='y')
model.k_points([8,1,8])
model.calculate('relax')

# %%
#Step 4 - Scf calculation
model.get_structure('relax') #Get relaxed strucutre
model.calculate('scf')

# %%
# Step 5 - Run ph.x
model.set_q(nq1=6,nq2=1,nq3=6) #Set parameters
model.calculate('ph')

# %%
#Step- 2 - Run q2r.x
model.calculate('q2r') #Run calculation

# %%
#Step 5 - Bands calculation
# path = ['GAMMA','X',"U","Z","GAMMA"] #define corners
path = ['U','X',"GAMMA","Z","U"] #define corners
model.band_points(path,number=50) #define path
model.calculate('bands')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Desktop/espresso-machine/src/espresso_machine/structure.py:88, in process_structure_core(filecontent, fileformat, call_source, logger, flask_request)
#      87 try:
# ---> 88     structure_tuple = get_structure_tuple(
#      89         fileobject, fileformat, extra_data=None
#      90     )
#      91 except UnknownFormatError:
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/tools_barebone/structure_importers/__init__.py:227, in get_structure_tuple(fileobject, fileformat, extra_data)
#     226 fileobject.seek(0)
# --> 227 pwfile = qe_tools.parsers.PwInputFile(
#     228     fileobject.read(), validate_species_names=True
#     229 )
#     230 pwparsed = pwfile.structure
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/qe_tools/parsers/_pw_input.py:158, in PwInputFile.__init__(self, content, qe_version, validate_species_names)
#     130 """
#     131 Parse inputs's namelist and cards to create attributes of the info.
#     132
#    (...)
#     155     parsing the content.
#     156 """
# --> 158 super().__init__(content, qe_version=qe_version, validate_species_names=validate_species_names)
#     160 # Parse the K_POINTS card.
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/qe_tools/parsers/_input_base.py:201, in _BaseInputFile.__init__(self, content, qe_version, validate_species_names)
#     199 self.atomic_species = _parse_atomic_species(self._input_txt, validate_species_names=validate_species_names)
# --> 201 self.structure = _parse_structure(
#     202     txt=self._input_txt,
#     203     namelists=self.namelists,
#     204     atomic_positions=self.atomic_positions,
#     205     atomic_species=self.atomic_species,
#     206     cell_parameters=self.cell_parameters,
#     207     qe_version=self._qe_version
#     208 )
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/qe_tools/parsers/_input_base.py:1087, in _parse_structure(txt, namelists, atomic_species, atomic_positions, cell_parameters, qe_version)
#    1085     using_celldm = None
# -> 1087 cell = _get_cell_from_parameters(cell_parameters, system_dict, alat, using_celldm, qe_version=qe_version)
#    1089 ################## POSITIONS #######################
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/qe_tools/parsers/_input_base.py:839, in _get_cell_from_parameters(cell_parameters, system_dict, alat, using_celldm, qe_version)
#     836 if ibrav == 0:
#     837     # The cell is defined explicitly in a block CELL_PARAMETERS
#     838     # Match the cell block using the regex defined above:
# --> 839     cell = np.array(cell_parameters['cell'])
#     840     cell_unit = cell_parameters['units']
#
# TypeError: 'NoneType' object is not subscriptable
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 #Step 5 - Bands calculation
#       2 # path = ['GAMMA','X',"U","Z","GAMMA"] #define corners
#       3 path = ['U','X',"GAMMA","Z","U"] #define corners
# ----> 4 model.band_points(path,number=50) #define path
#       5 model.calculate('bands')
#
# File ~/Desktop/espresso-machine/src/espresso_machine/project.py:82, in project.band_points(self, path, number)
#      80 def band_points(self,path,number):
#      81     self.path=path
# ---> 82     points = self.get_points()
#      83     k_path = kpoints.band_input(path,points,number)
#      84     self.config['pw']['k_points_bands'] = k_path
#
# File ~/Desktop/espresso-machine/src/espresso_machine/project.py:144, in project.get_points(self, file_path, file_format)
#     142 if file_path==False:
#     143     file_path=f'./Projects/{self.project_id}/{self.job_id}/scf.in'
# --> 144 k_points = structure.get_k(file_path,file_format)
#     145 self.points=k_points
#     146 return k_points
#
# File ~/Desktop/espresso-machine/src/espresso_machine/structure.py:342, in get_k(fileContent, fileformat)
#     340 with open(fileContent) as file:
#     341     fileContent = file.read()
# --> 342 structure = process_structure_core(filecontent=fileContent,fileformat=fileformat)
#     343 kpoints = structure['kpoints_rel']
#     344 return (kpoints)
#
# File ~/Desktop/espresso-machine/src/espresso_machine/structure.py:113, in process_structure_core(filecontent, fileformat, call_source, logger, flask_request)
#     102 except Exception:
#     103     # There was an exception...
#     104     logme(
#     105         logger,
#     106         filecontent,
#    (...)
#     111         extra={"traceback": traceback.format_exc(), "form_data": form_data,},
#     112     )
# --> 113     raise FlaskRedirectException(
#     114         "I tried my best, but I wasn't able to load your "
#     115         "file in format '{}'...".format(fileformat)
#     116     )
#     118 if len(structure_tuple[1]) > MAX_NUMBER_OF_ATOMS:
#     119     ## Structure too big
#     120     logme(
#     121         logger,
#     122         filecontent,
#    (...)
#     127         extra={"number_of_atoms": len(structure_tuple[1]), "form_data": form_data,},
#     128     )
#
# NameError: name 'FlaskRedirectException' is not defined

# %%
#Step 6 - Plotting
model.plot('electron',ylim=[-3,3],save=True) #plot electron bands
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 #Step 6 - Plotting
# ----> 2 model.plot('electron',ylim=[-3,3],save=True) #plot electron bands
#
# File ~/Desktop/espresso-machine/src/espresso_machine/project.py:118, in project.plot(self, calculation, save, xlim, ylim)
#     117 def plot(self,calculation,save=False,xlim=False,ylim=False):
# --> 118     plots.plot(self,calculation,save,xlim,ylim)
#
# File ~/Desktop/espresso-machine/src/espresso_machine/plots.py:10, in plot(self, calculation, save, xlim, ylim)
#       8 def plot(self,calculation,save,xlim=False,ylim=False):
#       9     if calculation=='electron':
# ---> 10         plot_electron(self,ylim=ylim,save=save)
#      11     if calculation=='phonon':
#      12         plot_phonon(self,save=save)
#
# File ~/Desktop/espresso-machine/src/espresso_machine/plots.py:29, in plot_electron(self, ylim, show, save)
#      27 for band in range(len(bands)):
#      28     plt.plot(k, bands[band, :],c='black')
# ---> 29 plt.xticks(sym,self.path)
#      30 for i in range(1,len(sym)-1):
#      31     plt.axvline(sym[i],c='black')
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2157, in xticks(ticks, labels, minor, **kwargs)
#    2155         l._internal_update(kwargs)
#    2156 else:
# -> 2157     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2159 return locs, labels_out
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/Desktop/espresso-machine/.venv/lib/python3.10/site-packages/matplotlib/axis.py:2050, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2047     labels = [t.get_text() if hasattr(t, 'get_text') else t
#    2048               for t in labels]
#    2049 except TypeError:
# -> 2050     raise TypeError(f"{labels:=} must be a sequence") from None
#    2051 locator = (self.get_minor_locator() if minor
#    2052            else self.get_major_locator())
#    2053 if not labels:
#    2054     # eg labels=[]:
#
# TypeError: 0 must be a sequence

# %%
#Step 3 - Run matdyn.x
num_points = 200 # Number of q points
model.calculate("matdyn") #Run calculation
# Out:
# matdyn is finished

# %%
#Step 4 - Plotting
model.plot('phonon',save=True) # Plot phonon band

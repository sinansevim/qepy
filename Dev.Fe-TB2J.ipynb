# %%
from src import esma

# %%
def init_model():
    model = esma.project(project_id='Fe_TB2J')
    model.set_pseudo(path="/scratch/s.sevim/espresso-machine/Pseudopotentials/PBE/US")
    model.get_structure(format="poscar",path="/scratch/s.sevim/espresso-machine/Structures/Fe.poscar")
    model.set_cores(64)
    model.ecutwfc(100) #Set wavefunction cutoff
    model.ecutrho(1000) #Set wavefunction cutoff
    model.k_points([6,6,6]) #Set number of k points
    model.degauss(0.01) #Set degauss value
    model.conv_thr(1e-8) #Set convergence threshold
    model.smearing('mv')
    model.mixing_beta(0.2)
    model.electron_maxstep(500) #Max number of electron iteration
    model.exchange_maxstep(500) #Max number of exchange iteration
    model.mixing_mode('local-TF')
    model.etot_conv_thr(10**-5)
    model.forc_conv_thr(10**-4)
    return model

# %%
model = init_model()

# %%
fm = model.magnetize(magnetic_atom='Fe')[0]

# %%
fm.optimize(calculation='vc-relax',max_iter=1)
# Out:
# Starting vc-relax iteration 1
# vc-relax for fm is started
# vc-relax for fm is finished
# vc-relax is converged after 1 steps

# %%
fm.calculate('scf')
# Out:
# scf for fm is started
# scf for fm is finished

# %%
path = ['GAMMA','H','P','GAMMA','N','P','N','H'] #define corners
num_points = 40 #number of points
fm.band_points(path,num_points) #define path

# %%
fm.calculate('bands')
fm.plot('electron',ylim=[8,30]) #plot electron bands
# Out:
# bands for fm is started
# bands for fm is finished
# bands-pp for fm is started
# bands-pp for fm is finished

# %%
fm.scdm_mu(fm.fermi_energy())
fm.scdm_sigma(2)

# %%
fm.nosym(True)
fm.k_points([8,8,8],grid=True) #k mesh 
fm.calculate('nscf')
# Out:
# nscf for fm is started
# nscf for fm is finished

# %%
fm.calculate('wannier90')
# Out:
# wannier90 for fm is started
# wannier90 for fm is finished

# %%
fm.plot(calculation='wannier90',ylim=[-10,10])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 fm.plot(calculation='wannier90',ylim=[-10,10])
#
# File /scratch/s.sevim/espresso-machine/src/esma/project.py:192, in project.plot(self, calculation, save, xlim, ylim, figsize, save_name, title)
#     191 def plot(self,calculation,save=False,xlim=False,ylim=False,figsize=False,save_name=False,title=False):
# --> 192     plots.plot(self,calculation=calculation,save=save,xlim=xlim,ylim=ylim,figsize=figsize,save_name=save_name,title=title)
#
# File /scratch/s.sevim/espresso-machine/src/esma/plots.py:20, in plot(self, calculation, save, xlim, ylim, figsize, save_name, title)
#      18     plot_kdos(self,ylim=ylim,save=save)
#      19 if calculation=='wannier90':
# ---> 20     plot_wannier90(self,ylim=ylim,save=save)
#
# File /scratch/s.sevim/espresso-machine/src/esma/plots.py:31, in plot_wannier90(self, ylim, save)
#      29 for band in range(len(bands)):
#      30     plt.plot(k, bands[band, :]-ef,c='black',linestyle='--')
# ---> 31 data = np.loadtxt(f'./Projects/{self.project_id}/{self.job_id}/{self.job_id}_band.dat')
#      32 sym = np.loadtxt(f"./Projects/{self.project_id}/{self.job_id}/{self.job_id}_band.labelinfo.dat",dtype=str)
#      33 kpt = sym.T[1].astype(int)[-1]
#
# File /scratch/s.sevim/espresso-machine/.venv/lib/python3.12/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File /scratch/s.sevim/espresso-machine/.venv/lib/python3.12/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File /scratch/s.sevim/espresso-machine/.venv/lib/python3.12/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /scratch/s.sevim/espresso-machine/.venv/lib/python3.12/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ./Projects/Fe_TB2J/fm/fm_band.dat not found.
